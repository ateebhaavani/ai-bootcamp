# %%
# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread(r"C:\Users\Ateebha\OneDrive\Pictures\WhatsApp Image 2025-11-28 at 18.39.24_fe77b5a0.jpg")
print(type(img))
print(img.shape)# 1st and 2nd values are for  height and width and 3rd value is  for colour mode
# Out:
# <class 'numpy.ndarray'>
# (1142, 895, 3)

# %%
cv2.imshow("bootcamp",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

print(img.shape)

# %%
img_resize = cv2.resize(img,(200,300))

# %%
cv2.imshow("ateebha",img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

print(img_resize.shape)
(300, 200, 3)

# %%
img_crop = img[100:300,200:500]

cv2.imshow("Cropped Image",img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite(r"croppedImg16.jpg",img_crop)

# %%
img_flip = cv2.flip(img,1)

cv2.imshow("flipped Image",img_flip)
cv2.waitKey(0)
cv2.destroyAllWindows()
