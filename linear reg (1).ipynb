# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Voltage and power data
X = np.array([1, 2, 3, 4, 5, 6]).reshape(-1, 1)
y = np.array([10, 20, 29, 41, 50, 61])

model = LinearRegression()

model.fit(X, y)

# Predict power for 7 volts
prediction = model.predict([[7]])

print("Predicted power at 7 volts:", prediction[0])

# Plot
plt.scatter(X, y)
plt.plot(X, model.predict(X))

plt.xlabel("Voltage")
plt.ylabel("Power")
plt.title("Voltage vs Power Consumption")

plt.show()
# Out:
# Predicted power at 7 volts: 70.86666666666666
