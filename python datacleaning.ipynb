# %%
import pandas as pd

data = {"Name": ["sam123", "Rahul45", "Priya78"]}

df = pd.DataFrame(data)

df["Name"] = df["Name"].str.replace(r"[0-9]", "", regex=True)

print(df)
# Out:
#     Name
# 0    sam
# 1  Rahul
# 2  Priya
