# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Customer data
data = np.array([
    [10, 2],
    [12, 3],
    [15, 2],
    [50, 10],
    [55, 12],
    [60, 11],
    [90, 20],
    [95, 22],
    [100, 21]
])

# Create K-Means model
model = KMeans(n_clusters=3, random_state=42)

# Train model
model.fit(data)

# Get clusters
labels = model.labels_

print("Cluster labels:")
print(labels)

# Plot clusters
plt.scatter(data[:, 0], data[:, 1], c=labels)

plt.xlabel("Annual Spending")
plt.ylabel("Number of Purchases")
plt.title("Customer Clustering")

plt.show()
# Out:
# C:\Users\Ateebha\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster labels:
# [2 2 2 0 0 0 1 1 1]
